# %%
import pandas as pd
import numpy as np

# %%
# accessing the excell file 
df=pd.read_excel("pandas_practice_dataset.xlsx")
# print data set
print(df)
# Out:
#           OrderID  OrderDate        ShipMode      Segment   Region  \
# 0    CA-2026-1000 2026-02-08  Standard Class  Home Office  Central
# 1    CA-2026-1001 2026-02-21  Standard Class     Consumer     East
# 2    CA-2026-1002 2026-01-29    Second Class     Consumer     West
# 3    CA-2026-1003 2026-01-15    Second Class     Consumer     West
# 4    CA-2026-1004 2026-02-12  Standard Class  Home Office     West
# ..            ...        ...             ...          ...      ...
# 145  CA-2026-1145 2026-01-07             NaN    Corporate    South
# 146  CA-2026-1146 2026-01-09     First Class     Consumer     East
# 147  CA-2026-1147 2026-01-08  Standard Class     Consumer     East
# 148  CA-2026-1148 2026-01-12  Standard Class    Corporate  Central
# 149  CA-2026-1149 2026-02-03    Second Class     Consumer    South
#
#             Category  SubCategory    Sales  Quantity  Discount  Profit  \
# 0        Electronics       Phones   234.79         8       0.5     NaN
# ...

# %%
# to see all the columns
df.columns
# Out:
# Index(['OrderID', 'OrderDate', 'ShipMode', 'Segment', 'Region', 'Category',
#        'SubCategory', 'Sales', 'Quantity', 'Discount', 'Profit', 'Returned'],
#       dtype='object')

# %%
# to get full information of all columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   OrderID      150 non-null    object
#  1   OrderDate    150 non-null    datetime64[ns]
#  2   ShipMode     143 non-null    object
#  3   Segment      150 non-null    object
#  4   Region       150 non-null    object
#  5   Category     150 non-null    object
#  6   SubCategory  150 non-null    object
#  7   Sales        145 non-null    float64
#  8   Quantity     150 non-null    int64
#  9   Discount     150 non-null    float64
#  10  Profit       142 non-null    float64
#  11  Returned     150 non-null    bool
# dtypes: bool(1), datetime64[ns](1), float64(3), int64(1), object(6)
# memory usage: 13.2+ KB

# %%
# to see number of row and number of columns
df.shape
# Out:
# (150, 12)

# %%
# to see the which column have which data type
df.dtypes
# Out:
# OrderID                object
# OrderDate      datetime64[ns]
# ShipMode               object
# Segment                object
# Region                 object
# Category               object
# SubCategory            object
# Sales                 float64
# Quantity                int64
# Discount              float64
# Profit                float64
# Returned                 bool
# dtype: object

# %%
# to see mathematical summary of numerical columns 
df.describe()
# Out:
#                  OrderDate         Sales    Quantity    Discount        Profit
# count                  150    145.000000  150.000000  150.000000    142.000000
# mean   2026-01-30 09:07:12    669.651517    4.913333    0.129333    413.496549
# min    2026-01-01 00:00:00     28.990000    1.000000    0.000000  -1525.670000
# 25%    2026-01-15 00:00:00    251.570000    3.000000    0.000000    -26.240000
# 50%    2026-01-28 12:00:00    497.150000    5.000000    0.100000    117.610000
# 75%    2026-02-14 00:00:00    799.910000    7.000000    0.200000    555.025000
# max    2026-03-01 00:00:00  12000.500000    9.000000    0.500000  20308.550000
# std                    NaN   1198.800965    2.572275    0.162012   1807.947607
